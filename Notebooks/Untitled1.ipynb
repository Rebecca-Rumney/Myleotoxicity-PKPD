# %%
from Code.PD_model import PD_friberg_result
from Code.PD_model import PintsPDFribergLinE(pints.ForwardModel)
import numpy as np

# %%
parameter = [0.68, 2.8, 4.9, 2.3,
    861.3402342100585, 
    55.20000000000002, 
    0.158113883008419, 
    1.0000000000000004]
times = np.load("../Data_and_parameters/PD_real/data_times_Docetaxel_Platelets .npy")

# %%
PD_friberg_result(0.0, 2, parameter, times, E_max=False, num_transit=3)
# Out:
# time to set current state: 3.750999894691631e-06 seconds, 0.0009130719990935177 seconds
# time to calculate transfer: 1.6404001144110225e-05 seconds
# time to set calculate differential: 1.064100069925189e-05 seconds, 2.9150014597689733e-06 seconds, 1.2869986676378176e-06 seconds
# time to do final concatenation: 1.030300154525321e-05 seconds
# time to set current state: 2.929999027401209e-06 seconds, 0.00037901500036241487 seconds
# time to calculate transfer: 1.327800055150874e-05 seconds
# time to set calculate differential: 9.424000381841324e-06 seconds, 2.5110002752626315e-06 seconds, 1.2580003385664895e-06 seconds
# time to do final concatenation: 2.4463999579893425e-05 seconds
# time to set current state: 2.4550008674850687e-06 seconds, 0.00021159500101930462 seconds
# time to calculate transfer: 1.2073998732375912e-05 seconds
# time to set calculate differential: 1.3038999895798042e-05 seconds, 2.303999281139113e-06 seconds, 9.90999978967011e-07 seconds
# ...

# %%
PD_friberg_result(1.0, 2, parameter, times, E_max=False, num_transit=3)

# %%
PD_friberg_result(2.0, 2, parameter, times, E_max=False, num_transit=3)

# %%
PD_friberg_result(3.0, 2, parameter, times, E_max=False, num_transit=3)
